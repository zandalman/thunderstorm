# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import const
from types import SimpleNamespace
from helper import *

# %%
# read data
sim  = 'weak'
data = np.load(os.path.join('..', 'rprocess', '%s.npz' % sim), allow_pickle=True)
data = SimpleNamespace(**data)

# %%
plt.plot(data.time, data.ab_elem[:, 1])
plt.plot(data.time, data.ab_elem[:, 51])
plt.plot(data.time, data.ab_elem[:, 53])
plt.plot(data.time, data.ab_elem[:, 54])
plt.plot(data.time, data.ab_elem[:, 55])

plt.xscale('log')

# %%
plt.loglog(data.time/const.day, data.temp)

# %%
plt.loglog(data.time/const.day, data.rho)
